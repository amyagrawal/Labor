# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from dateutil.relativedelta import relativedelta
import seaborn as sns
import statsmodels.api as sm  
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('ASOS.csv', index_col=0)
df.index.name=None
df.reset_index(inplace=True)
df.drop(df.index[129], inplace=True)

# %%
start = datetime.datetime.strptime("2006-01-01", "%Y-%m-%d")
date_list = [start + relativedelta(months=x) for x in range(0,129)]
df['index'] =date_list
df.set_index(['index'], inplace=True)
df.index.name=None

# %%
df.columns= ['GSO_LF','GSO_UR','CLT_LF', 'CLT_UR', 'RDU_LF',
             'RDU_UR', 'Harrisburg_LF', 'Harrisburg_UR', 'USA_LF',
             'USA_UR']

# %%
df.CLT_LF.plot(figsize=(12,8), title= 'CLT Labor Force', fontsize=14).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('month_ridership.png', bbox_inches='tight')

# %%
df.Harrisburg_LF.plot(figsize=(12,8), title= 'Harrisburg Labor Force', fontsize=14).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('month_ridership.png', bbox_inches='tight')

# %%
decomposition_CLT = seasonal_decompose(df.CLT_LF, freq=12)  
fig = plt.figure()  
fig = decomposition_CLT.plot()
fig.set_size_inches(15, 8)

# %%
decomposition_Harrisburg = seasonal_decompose(df.Harrisburg_LF, freq=12)  
fig = plt.figure()  
fig = decomposition_Harrisburg.plot()  
fig.set_size_inches(15, 8)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print 'Results of Dickey-Fuller Test:'
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print dfoutput

# %%
test_stationarity(df.CLT_LF)
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.025396
# p-value                          0.743889
# #Lags Used                       0.000000
# Number of Observations Used    128.000000
# Critical Value (5%)             -2.884398
# Critical Value (1%)             -3.482501
# Critical Value (10%)            -2.578960
# dtype: float64

# %%
test_stationarity(df.Harrisburg_LF)
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.439047
# p-value                          0.563420
# #Lags Used                      13.000000
# Number of Observations Used    115.000000
# Critical Value (5%)             -2.887020
# Critical Value (1%)             -3.488535
# Critical Value (10%)            -2.580360
# dtype: float64

# %%
df['CLT_first_difference'] = df.CLT_LF - df.CLT_LF.shift(1)  
test_stationarity(df.CLT_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -1.199855e+01
# p-value                        3.388677e-22
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.270000e+02
# Critical Value (5%)           -2.884580e+00
# Critical Value (1%)           -3.482920e+00
# Critical Value (10%)          -2.579058e+00
# dtype: float64

# %%
df['Harrisburg_first_difference'] = df.Harrisburg_LF - df.Harrisburg_LF.shift(1)  
test_stationarity(df.Harrisburg_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.440573
# p-value                          0.130611
# #Lags Used                      13.000000
# Number of Observations Used    114.000000
# Critical Value (5%)             -2.887246
# Critical Value (1%)             -3.489058
# Critical Value (10%)            -2.580481
# dtype: float64

# %%
df['CLT_seasonal_difference'] = df.CLT_LF - df.CLT_LF.shift(12)  
test_stationarity(df.CLT_seasonal_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.268473
# p-value                          0.182338
# #Lags Used                      12.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
df['Harrisburg_seasonal_difference'] = df.Harrisburg_LF - df.Harrisburg_LF.shift(12)  
test_stationarity(df.Harrisburg_seasonal_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.146775
# p-value                          0.226126
# #Lags Used                      12.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
df['CLT_seasonal_first_difference'] = df.CLT_first_difference - df.CLT_first_difference.shift(12)  
test_stationarity(df.CLT_seasonal_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.481468
# p-value                          0.000002
# #Lags Used                      11.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
df['Harrisburg_seasonal_first_difference'] = df.Harrisburg_first_difference - df.Harrisburg_first_difference.shift(12)  
test_stationarity(df.Harrisburg_seasonal_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.606127
# p-value                          0.000126
# #Lags Used                      11.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.CLT_seasonal_first_difference.iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.CLT_seasonal_first_difference.iloc[13:], lags=40, ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.Harrisburg_seasonal_first_difference.iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.Harrisburg_seasonal_first_difference.iloc[13:], lags=40, ax=ax2)

# %%
mod = sm.tsa.statespace.SARIMAX(df.CLT_LF, trend='n', order=(0,1,0), seasonal_order=(0,1,1,12))
results_CLT = mod.fit()
print results_CLT.summary()
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                             CLT_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(0, 1, 1, 12)   Log Likelihood               -1231.305
# Date:                            Fri, 23 Dec 2016   AIC                           2466.610
# Time:                                    10:01:05   BIC                           2472.329
# Sample:                                01-01-2006   HQIC                          2468.934
#                                      - 09-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L12      -0.0097      0.008     -1.145      0.252      -0.026       0.007
# sigma2      4.486e+07    1.9e-11   2.37e+18      0.000    4.49e+07    4.49e+07
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(df.Harrisburg_LF, trend='n', order=(0,1,0), seasonal_order=(0,1,1,12))
results_Harrisburg = mod.fit()
print results_Harrisburg.summary()
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                      Harrisburg_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(0, 1, 1, 12)   Log Likelihood               -1015.001
# Date:                            Fri, 23 Dec 2016   AIC                           2034.002
# Time:                                    10:01:14   BIC                           2039.721
# Sample:                                01-01-2006   HQIC                          2036.326
#                                      - 09-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L12      -0.0145      0.019     -0.748      0.454      -0.052       0.023
# sigma2      2.321e+06   1.49e+05     15.555      0.000    2.03e+06    2.61e+06
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(df.CLT_LF, trend='n', order=(0,1,0), seasonal_order=(1,1,1,12))
results_CLT = mod.fit()
print results_CLT.summary()
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                             CLT_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood               -1223.205
# Date:                            Fri, 23 Dec 2016   AIC                           2452.409
# Time:                                    10:01:29   BIC                           2460.989
# Sample:                                01-01-2006   HQIC                          2455.895
#                                      - 09-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.9998   1.05e-06   9.52e+05      0.000       1.000       1.000
# ma.S.L12      -1.0000    4.2e-07  -2.38e+06      0.000      -1.000      -1.000
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(df.Harrisburg_LF, trend='n', order=(0,1,0), seasonal_order=(1,1,1,12))
results_Harrisburg = mod.fit()
print results_Harrisburg.summary()
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                      Harrisburg_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood               -1016.164
# Date:                            Fri, 23 Dec 2016   AIC                           2038.328
# Time:                                    10:01:38   BIC                           2046.908
# Sample:                                01-01-2006   HQIC                          2041.814
#                                      - 09-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.9999   2.51e-07  -3.99e+06      0.000      -1.000      -1.000
# ma.S.L12       0.9999   2.07e-07   4.83e+06      0.000       1.000       1.000
# ...

# %%
df['CLT_forecast'] = results_CLT.predict(start = 118, end= 130, dynamic= True)  
df[['CLT_LF', 'CLT_forecast']].plot(figsize=(12, 8)) 
#plt.savefig('ts_df_predict.png', bbox_inches='tight')
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\statsmodels\base\data.py:551: FutureWarning: TimeSeries is deprecated. Please use Series
#   return TimeSeries(squeezed, index=self.predict_dates)

# %%
df['Harrisburg_forecast'] = results_Harrisburg.predict(start = 118, end= 130, dynamic= True)  
df[['Harrisburg_LF', 'Harrisburg_forecast']].plot(figsize=(12, 8)) 
#plt.savefig('ts_df_predict.png', bbox_inches='tight')

# %%
df
# Out:
#             GSO_LF  GSO_UR   CLT_LF  CLT_UR  RDU_LF  RDU_UR  Harrisburg_LF  \
# 2006-01-01  360198     4.7  1014866     4.9  245718     3.8         276661
# 2006-02-01  362938     5.0  1021495     5.2  247942     4.1         276445
# 2006-03-01  364353     4.5  1027071     4.7  249102     3.7         278255
# 2006-04-01  366655     4.5  1032285     4.7  248950     3.7         278101
# 2006-05-01  370078     4.7  1040587     4.9  251530     3.9         281095
# 2006-06-01  370414     5.1  1042765     5.3  254221     4.2         284704
# 2006-07-01  373952     5.4  1049796     5.4  257485     4.4         287259
# 2006-08-01  372268     5.1  1054405     5.2  256076     4.2         287051
# 2006-09-01  369509     4.7  1056308     4.8  255396     3.8         282479
# 2006-10-01  373487     4.4  1065042     4.6  256627     3.7         281671
# 2006-11-01  373985     4.8  1068547     4.9  258002     3.9         282554
# ...

# %%
npredict =df.CLT_LF['2016'].shape[0]
fig, ax = plt.subplots(figsize=(12,6))
npre = 12
ax.set(title='Labor Force', xlabel='Date', ylabel='Labor Force')
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'CLT_LF'], 'o', label='Observed CLT') 
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'CLT_forecast'], 'g', label='Dynamic forecast CLT')
legend = ax.legend(loc='lower right')
legend.get_frame().set_facecolor('w')
#plt.savefig('ts_predict_compare.png', bbox_inches='tight')

# %%
npredict =df.Harrisburg_LF['2016'].shape[0]
fig, ax = plt.subplots(figsize=(12,6))
npre = 12
ax.set(title='Labor Force', xlabel='Date', ylabel='Labor Force')
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'Harrisburg_LF'], 'o', label='Observed Harrisburg') 
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'Harrisburg_forecast'], 'g', label='Dynamic forecast Harrisburg')
legend = ax.legend(loc='lower right')
legend.get_frame().set_facecolor('w')
#plt.savefig('ts_predict_compare.png', bbox_inches='tight')

# %%
start = datetime.datetime.strptime("2016-11-01", "%Y-%m-%d")
date_list = [start + relativedelta(months=x) for x in range(0,62)]
future = pd.DataFrame(index=date_list, columns= df.columns)

# %%
df_new = pd.concat([df, future])

# %%
df_new
# Out:
#               GSO_LF  GSO_UR     CLT_LF  CLT_UR    RDU_LF  RDU_UR  \
# 2006-01-01  360198.0     4.7  1014866.0     4.9  245718.0     3.8
# 2006-02-01  362938.0     5.0  1021495.0     5.2  247942.0     4.1
# 2006-03-01  364353.0     4.5  1027071.0     4.7  249102.0     3.7
# 2006-04-01  366655.0     4.5  1032285.0     4.7  248950.0     3.7
# 2006-05-01  370078.0     4.7  1040587.0     4.9  251530.0     3.9
# 2006-06-01  370414.0     5.1  1042765.0     5.3  254221.0     4.2
# 2006-07-01  373952.0     5.4  1049796.0     5.4  257485.0     4.4
# 2006-08-01  372268.0     5.1  1054405.0     5.2  256076.0     4.2
# 2006-09-01  369509.0     4.7  1056308.0     4.8  255396.0     3.8
# 2006-10-01  373487.0     4.4  1065042.0     4.6  256627.0     3.7
# 2006-11-01  373985.0     4.8  1068547.0     4.9  258002.0     3.9
# 2006-12-01  372043.0     4.5  1061527.0     4.6  257527.0     3.6
# 2007-01-01  365442.0     5.2  1056454.0     5.1  252685.0     4.1
# ...

# %%
df_new['CLT_forecast'] = results_CLT.predict(start = 129, end = 190, dynamic= True)  
df_new[['CLT_LF', 'CLT_forecast']].ix[-191:].plot(figsize=(12, 8)).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('ts_predict_future.png', bbox_inches='tight')

# %%
df_new['Harrisburg_forecast'] = results_Harrisburg.predict(start = 129, end = 190, dynamic= True)  
df_new[['Harrisburg_LF', 'Harrisburg_forecast']].ix[-191:].plot(figsize=(12, 8)).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('ts_predict_future.png', bbox_inches='tight')

# %%
df_new[['CLT_LF', 'CLT_forecast', 'Harrisburg_LF', 'Harrisburg_forecast']].ix[-191:].plot(figsize=(12, 8)).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlabel('Year', fontsize=18)
plt.ylabel('Labor Force',fontsize=18)
plt.title('CLT vs Harrisburg Labor Force', fontsize=20)
import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)
plt.savefig('CLT vs Harrisburg Labor Force.jpeg', bbox_inches='tight')

# %%
df_new
# Out:
#               GSO_LF  GSO_UR     CLT_LF  CLT_UR    RDU_LF  RDU_UR  \
# 2006-01-01  360198.0     4.7  1014866.0     4.9  245718.0     3.8
# 2006-02-01  362938.0     5.0  1021495.0     5.2  247942.0     4.1
# 2006-03-01  364353.0     4.5  1027071.0     4.7  249102.0     3.7
# 2006-04-01  366655.0     4.5  1032285.0     4.7  248950.0     3.7
# 2006-05-01  370078.0     4.7  1040587.0     4.9  251530.0     3.9
# 2006-06-01  370414.0     5.1  1042765.0     5.3  254221.0     4.2
# 2006-07-01  373952.0     5.4  1049796.0     5.4  257485.0     4.4
# 2006-08-01  372268.0     5.1  1054405.0     5.2  256076.0     4.2
# 2006-09-01  369509.0     4.7  1056308.0     4.8  255396.0     3.8
# 2006-10-01  373487.0     4.4  1065042.0     4.6  256627.0     3.7
# 2006-11-01  373985.0     4.8  1068547.0     4.9  258002.0     3.9
# 2006-12-01  372043.0     4.5  1061527.0     4.6  257527.0     3.6
# 2007-01-01  365442.0     5.2  1056454.0     5.1  252685.0     4.1
# ...
