# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from dateutil.relativedelta import relativedelta
import seaborn as sns
import statsmodels.api as sm  
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('ASOS.csv', index_col=0)
df.index.name=None
df.reset_index(inplace=True)
df.drop(df.index[129], inplace=True)

# %%
start = datetime.datetime.strptime("2006-01-01", "%Y-%m-%d")
date_list = [start + relativedelta(months=x) for x in range(0,129)]
df['index'] =date_list
df.set_index(['index'], inplace=True)
df.index.name=None

# %%
df.columns= ['GSO_LF','GSO_UR','CLT_LF', 'CLT_UR', 'RDU_LF',
             'RDU_UR', 'Harrisburg_LF', 'Harrisburg_UR', 'USA_LF',
             'USA_UR']

# %%
df.CLT_LF.plot(figsize=(12,8), title= 'CLT Labor Force', fontsize=14).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('month_ridership.png', bbox_inches='tight')

# %%
df.RDU_LF.plot(figsize=(12,8), title= 'RDU Labor Force', fontsize=14).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('month_ridership.png', bbox_inches='tight')

# %%
decomposition_CLT = seasonal_decompose(df.CLT_LF, freq=12)  
fig = plt.figure()  
fig = decomposition_CLT.plot()
fig.set_size_inches(15, 8)

# %%
decomposition_RDU = seasonal_decompose(df.RDU_LF, freq=12)  
fig = plt.figure()  
fig = decomposition_RDU.plot()  
fig.set_size_inches(15, 8)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print 'Results of Dickey-Fuller Test:'
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print dfoutput

# %%
test_stationarity(df.CLT_LF)
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.025396
# p-value                          0.743889
# #Lags Used                       0.000000
# Number of Observations Used    128.000000
# Critical Value (5%)             -2.884398
# Critical Value (1%)             -3.482501
# Critical Value (10%)            -2.578960
# dtype: float64

# %%
test_stationarity(df.RDU_LF)
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                   0.143332
# p-value                          0.968898
# #Lags Used                      12.000000
# Number of Observations Used    116.000000
# Critical Value (5%)             -2.886797
# Critical Value (1%)             -3.488022
# Critical Value (10%)            -2.580241
# dtype: float64

# %%
df['CLT_first_difference'] = df.CLT_LF - df.CLT_LF.shift(1)  
test_stationarity(df.CLT_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -1.199855e+01
# p-value                        3.388677e-22
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.270000e+02
# Critical Value (5%)           -2.884580e+00
# Critical Value (1%)           -3.482920e+00
# Critical Value (10%)          -2.579058e+00
# dtype: float64

# %%
df['RDU_first_difference'] = df.RDU_LF - df.RDU_LF.shift(1)  
test_stationarity(df.RDU_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.402920
# p-value                          0.140914
# #Lags Used                      11.000000
# Number of Observations Used    116.000000
# Critical Value (5%)             -2.886797
# Critical Value (1%)             -3.488022
# Critical Value (10%)            -2.580241
# dtype: float64

# %%
df['CLT_seasonal_difference'] = df.CLT_LF - df.CLT_LF.shift(12)  
test_stationarity(df.CLT_seasonal_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.268473
# p-value                          0.182338
# #Lags Used                      12.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
df['RDU_seasonal_difference'] = df.RDU_LF - df.RDU_LF.shift(12)  
test_stationarity(df.RDU_seasonal_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.555618
# p-value                          0.102521
# #Lags Used                      12.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
df['CLT_seasonal_first_difference'] = df.CLT_first_difference - df.CLT_first_difference.shift(12)  
test_stationarity(df.CLT_seasonal_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.481468
# p-value                          0.000002
# #Lags Used                      11.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
df['RDU_seasonal_first_difference'] = df.RDU_first_difference - df.RDU_first_difference.shift(12)  
test_stationarity(df.RDU_seasonal_first_difference.dropna(inplace=False))
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.304976
# p-value                          0.014658
# #Lags Used                      11.000000
# Number of Observations Used    104.000000
# Critical Value (5%)             -2.889758
# Critical Value (1%)             -3.494850
# Critical Value (10%)            -2.581822
# dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.CLT_seasonal_first_difference.iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.CLT_seasonal_first_difference.iloc[13:], lags=40, ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.RDU_seasonal_first_difference.iloc[13:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.RDU_seasonal_first_difference.iloc[13:], lags=40, ax=ax2)

# %%
mod = sm.tsa.statespace.SARIMAX(df.CLT_LF, trend='n', order=(0,1,0), seasonal_order=(0,1,1,12))
results_CLT = mod.fit()
print results_CLT.summary()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             CLT_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(0, 1, 1, 12)   Log Likelihood               -1231.305
# Date:                            Fri, 23 Dec 2016   AIC                           2466.610
# Time:                                    10:25:49   BIC                           2472.329
# Sample:                                01-01-2006   HQIC                          2468.934
#                                      - 09-01-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L12      -0.0097      0.008     -1.145      0.252      -0.026       0.007
# sigma2      4.486e+07    1.9e-11   2.37e+18      0.000    4.49e+07    4.49e+07
# ===================================================================================
# Ljung-Box (Q):                       70.92   Jarque-Bera (JB):               803.23
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.69   Skew:                             0.55
# Prob(H) (two-sided):                  0.25   Kurtosis:                        15.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients.
# [2] Covariance matrix is singular or near-singular, with condition number 1.52e+34. Standard errors may be unstable.

# %%
mod = sm.tsa.statespace.SARIMAX(df.RDU_LF, trend='n', order=(0,1,0), seasonal_order=(0,1,1,12))
results_RDU = mod.fit()
print results_RDU.summary()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             RDU_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(0, 1, 1, 12)   Log Likelihood               -1032.479
# Date:                            Fri, 23 Dec 2016   AIC                           2068.958
# Time:                                    10:26:01   BIC                           2074.677
# Sample:                                01-01-2006   HQIC                          2071.282
#                                      - 09-01-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L12      -0.0599      0.025     -2.361      0.018      -0.110      -0.010
# sigma2      2.795e+06   2.91e+05      9.614      0.000    2.23e+06    3.36e+06
# ===================================================================================
# Ljung-Box (Q):                       52.02   Jarque-Bera (JB):                 2.15
# Prob(Q):                              0.10   Prob(JB):                         0.34
# Heteroskedasticity (H):               1.33   Skew:                             0.15
# Prob(H) (two-sided):                  0.38   Kurtosis:                         3.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients.

# %%
mod = sm.tsa.statespace.SARIMAX(df.CLT_LF, trend='n', order=(0,1,0), seasonal_order=(1,1,1,12))
results_CLT = mod.fit()
print results_CLT.summary()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             CLT_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood               -1223.205
# Date:                            Fri, 23 Dec 2016   AIC                           2452.409
# Time:                                    10:26:10   BIC                           2460.989
# Sample:                                01-01-2006   HQIC                          2455.895
#                                      - 09-01-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.9998   1.05e-06   9.52e+05      0.000       1.000       1.000
# ma.S.L12      -1.0000    4.2e-07  -2.38e+06      0.000      -1.000      -1.000
# sigma2      5.928e+07   4.27e-14   1.39e+21      0.000    5.93e+07    5.93e+07
# ===================================================================================
# Ljung-Box (Q):                       74.75   Jarque-Bera (JB):               798.41
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.69   Skew:                             0.48
# Prob(H) (two-sided):                  0.26   Kurtosis:                        15.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients.
# [2] Covariance matrix is singular or near-singular, with condition number 4.75e+30. Standard errors may be unstable.

# %%
mod = sm.tsa.statespace.SARIMAX(df.RDU_LF, trend='n', order=(0,1,0), seasonal_order=(1,1,1,12))
results_RDU = mod.fit()
print results_RDU.summary()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             RDU_LF   No. Observations:                  129
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood               -1032.586
# Date:                            Fri, 23 Dec 2016   AIC                           2071.172
# Time:                                    10:26:20   BIC                           2079.752
# Sample:                                01-01-2006   HQIC                          2074.658
#                                      - 09-01-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.1099      0.007    -15.595      0.000      -0.124      -0.096
# ma.S.L12       0.0519      0.004     11.553      0.000       0.043       0.061
# sigma2      2.611e+06   1.85e-10   1.41e+16      0.000    2.61e+06    2.61e+06
# ===================================================================================
# Ljung-Box (Q):                       53.97   Jarque-Bera (JB):                 2.61
# Prob(Q):                              0.07   Prob(JB):                         0.27
# Heteroskedasticity (H):               1.38   Skew:                             0.15
# Prob(H) (two-sided):                  0.32   Kurtosis:                         3.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients.
# [2] Covariance matrix is singular or near-singular, with condition number 9.57e+31. Standard errors may be unstable.

# %%
df['CLT_forecast'] = results_CLT.predict(start = 118, end= 130, dynamic= True)  
df[['CLT_LF', 'CLT_forecast']].plot(figsize=(12, 8)) 
#plt.savefig('ts_df_predict.png', bbox_inches='tight')
# Out:
# C:\Users\akumar\AppData\Local\Continuum\Anaconda2\lib\site-packages\statsmodels\base\data.py:551: FutureWarning: TimeSeries is deprecated. Please use Series
#   return TimeSeries(squeezed, index=self.predict_dates)

# %%
df['RDU_forecast'] = results_RDU.predict(start = 118, end= 130, dynamic= True)  
df[['RDU_LF', 'RDU_forecast']].plot(figsize=(12, 8)) 
#plt.savefig('ts_df_predict.png', bbox_inches='tight')

# 2016-03-01                   9090.0                        15019.0
# 2016-04-01                   5697.0                        -9481.0
# 2016-05-01                   3355.0                       -16948.0
# 2016-06-01                   4596.0                         8646.0
# 2016-07-01                   4607.0                        -6791.0
# 2016-08-01                   4309.0                         3560.0
# 2016-09-01                   8636.0                         9342.0
#
#             RDU_seasonal_first_difference  CLT_forecast   RDU_forecast
# 2006-01-01                            NaN           NaN            NaN
# 2006-02-01                            NaN           NaN            NaN
# 2006-03-01                            NaN           NaN            NaN
# 2006-04-01                            NaN           NaN            NaN
# 2006-05-01                            NaN           NaN            NaN
# 2006-06-01                            NaN           NaN            NaN
# 2006-07-01                            NaN           NaN            NaN
# 2006-08-01                            NaN           NaN            NaN
# 2006-09-01                            NaN           NaN            NaN
# 2006-10-01                            NaN           NaN            NaN
# 2006-11-01                            NaN           NaN            NaN
# 2006-12-01                            NaN           NaN            NaN
# 2007-01-01                            NaN           NaN            NaN
# 2007-02-01                         -973.0           NaN            NaN
# 2007-03-01                         -331.0           NaN            NaN
# 2007-04-01                        -1115.0           NaN            NaN
# 2007-05-01                        -1929.0           NaN            NaN
# 2007-06-01                          515.0           NaN            NaN
# 2007-07-01                         -571.0           NaN            NaN
# 2007-08-01                        -1599.0           NaN            NaN
# 2007-09-01                         1677.0           NaN            NaN
# 2007-10-01                        -3711.0           NaN            NaN
# 2007-11-01                          140.0           NaN            NaN
# 2007-12-01                         -913.0           NaN            NaN
# 2008-01-01                         8399.0           NaN            NaN
# 2008-02-01                         -986.0           NaN            NaN
# 2008-03-01                          579.0           NaN            NaN
# 2008-04-01                         2538.0           NaN            NaN
# 2008-05-01                          234.0           NaN            NaN
# 2008-06-01                        -1228.0           NaN            NaN
# ...                                   ...           ...            ...
# 2014-04-01                        -1921.0           NaN            NaN
# 2014-05-01                          231.0           NaN            NaN
# 2014-06-01                        -1543.0           NaN            NaN
# 2014-07-01                         2293.0           NaN            NaN
# 2014-08-01                         1642.0           NaN            NaN
# 2014-09-01                        -1911.0           NaN            NaN
# 2014-10-01                         2852.0           NaN            NaN
# 2014-11-01                        -1169.0           NaN            NaN
# 2014-12-01                          625.0           NaN            NaN
# 2015-01-01                         3388.0           NaN            NaN
# 2015-02-01                         -663.0           NaN            NaN
# 2015-03-01                        -2496.0           NaN            NaN
# 2015-04-01                         2330.0           NaN            NaN
# 2015-05-01                         2045.0           NaN            NaN
# 2015-06-01                        -2559.0           NaN            NaN
# 2015-07-01                        -1212.0           NaN            NaN
# 2015-08-01                        -1023.0           NaN            NaN
# 2015-09-01                          -93.0           NaN            NaN
# 2015-10-01                         -945.0           NaN            NaN
# 2015-11-01                          545.0  1.238332e+06  280782.596580
# 2015-12-01                         1484.0  1.233777e+06  278805.831636
# 2016-01-01                        -2825.0  1.241192e+06  282233.583597
# 2016-02-01                         2817.0  1.249496e+06  284202.548198
# 2016-03-01                         3681.0  1.250779e+06  283615.743553
# 2016-04-01                        -3393.0  1.256726e+06  285142.789166
# 2016-05-01                        -2342.0  1.274439e+06  287859.123790
# 2016-06-01                         1241.0  1.270131e+06  284158.763708
# 2016-07-01                           11.0  1.269631e+06  286615.886422
# 2016-08-01                         -298.0  1.258205e+06  283820.076607
# 2016-09-01                         4327.0  1.254552e+06  283501.964462
#
# [129 rows x 18 columns]

# %%
npredict =df.CLT_LF['2016'].shape[0]
fig, ax = plt.subplots(figsize=(12,6))
npre = 12
ax.set(title='Labor Force', xlabel='Date', ylabel='Labor Force')
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'CLT_LF'], 'o', label='Observed CLT') 
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'CLT_forecast'], 'g', label='Dynamic forecast CLT')
legend = ax.legend(loc='lower right')
legend.get_frame().set_facecolor('w')
#plt.savefig('ts_predict_compare.png', bbox_inches='tight')

# %%
npredict =df.RDU_LF['2016'].shape[0]
fig, ax = plt.subplots(figsize=(12,6))
npre = 12
ax.set(title='Labor Force', xlabel='Date', ylabel='Labor Force')
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'RDU_LF'], 'o', label='Observed GSO') 
ax.plot(df.index[-npredict-npre+1:], df.ix[-npredict-npre+1:, 'RDU_forecast'], 'g', label='Dynamic forecast GSO')
legend = ax.legend(loc='lower right')
legend.get_frame().set_facecolor('w')
#plt.savefig('ts_predict_compare.png', bbox_inches='tight')

# %%
start = datetime.datetime.strptime("2016-11-01", "%Y-%m-%d")
date_list = [start + relativedelta(months=x) for x in range(0,62)]
future = pd.DataFrame(index=date_list, columns= df.columns)

# %%
df_new = pd.concat([df, future])

# %%
df_new
# Out:
#               GSO_LF  GSO_UR     CLT_LF  CLT_UR    RDU_LF  RDU_UR  \
# 2006-01-01  360198.0     4.7  1014866.0     4.9  245718.0     3.8
# 2006-02-01  362938.0     5.0  1021495.0     5.2  247942.0     4.1
# 2006-03-01  364353.0     4.5  1027071.0     4.7  249102.0     3.7
# 2006-04-01  366655.0     4.5  1032285.0     4.7  248950.0     3.7
# 2006-05-01  370078.0     4.7  1040587.0     4.9  251530.0     3.9
# 2006-06-01  370414.0     5.1  1042765.0     5.3  254221.0     4.2
# 2006-07-01  373952.0     5.4  1049796.0     5.4  257485.0     4.4
# 2006-08-01  372268.0     5.1  1054405.0     5.2  256076.0     4.2
# 2006-09-01  369509.0     4.7  1056308.0     4.8  255396.0     3.8
# 2006-10-01  373487.0     4.4  1065042.0     4.6  256627.0     3.7
# 2006-11-01  373985.0     4.8  1068547.0     4.9  258002.0     3.9
# 2006-12-01  372043.0     4.5  1061527.0     4.6  257527.0     3.6
# 2007-01-01  365442.0     5.2  1056454.0     5.1  252685.0     4.1
# 2007-02-01  365760.0     5.2  1057116.0     4.9  253936.0     4.0
# 2007-03-01  366472.0     4.6  1062016.0     4.5  254765.0     3.6
# 2007-04-01  365491.0     4.6  1060630.0     4.8  253498.0     3.7
# 2007-05-01  366008.0     4.7  1067236.0     5.0  254149.0     3.7
# 2007-06-01  367395.0     5.1  1069716.0     5.2  257355.0     4.2
# 2019-09-01            NaN            NaN       NaN     NaN
# 2019-10-01            NaN            NaN       NaN     NaN
# 2019-11-01            NaN            NaN       NaN     NaN
# 2019-12-01            NaN            NaN       NaN     NaN
# 2020-01-01            NaN            NaN       NaN     NaN
# 2020-02-01            NaN            NaN       NaN     NaN
# 2020-03-01            NaN            NaN       NaN     NaN
# 2020-04-01            NaN            NaN       NaN     NaN
# 2020-05-01            NaN            NaN       NaN     NaN
# 2020-06-01            NaN            NaN       NaN     NaN
# 2020-07-01            NaN            NaN       NaN     NaN
# 2020-08-01            NaN            NaN       NaN     NaN
# 2020-09-01            NaN            NaN       NaN     NaN
# 2020-10-01            NaN            NaN       NaN     NaN
# 2020-11-01            NaN            NaN       NaN     NaN
# 2020-12-01            NaN            NaN       NaN     NaN
# 2021-01-01            NaN            NaN       NaN     NaN
# 2021-02-01            NaN            NaN       NaN     NaN
# 2021-03-01            NaN            NaN       NaN     NaN
# 2021-04-01            NaN            NaN       NaN     NaN
# 2021-05-01            NaN            NaN       NaN     NaN
# 2021-06-01            NaN            NaN       NaN     NaN
# 2021-07-01            NaN            NaN       NaN     NaN
# 2021-08-01            NaN            NaN       NaN     NaN
# 2021-09-01            NaN            NaN       NaN     NaN
# 2021-10-01            NaN            NaN       NaN     NaN
# 2021-11-01            NaN            NaN       NaN     NaN
# 2021-12-01            NaN            NaN       NaN     NaN
#
#             CLT_first_difference  RDU_first_difference  \
# 2006-01-01                   NaN                   NaN
# 2006-02-01                6629.0                2224.0
# 2006-03-01                5576.0                1160.0
# 2006-04-01                5214.0                -152.0
# 2006-05-01                8302.0                2580.0
# 2006-06-01                2178.0                2691.0
# 2006-07-01                7031.0                3264.0
# 2006-08-01                4609.0               -1409.0
# 2006-09-01                1903.0                -680.0
# 2006-10-01                8734.0                1231.0
# 2006-11-01                3505.0                1375.0
# 2006-12-01               -7020.0                -475.0
# 2007-01-01               -5073.0               -4842.0
# 2007-02-01                 662.0                1251.0
# 2007-03-01                4900.0                 829.0
# 2007-04-01               -1386.0               -1267.0
# 2007-05-01                6606.0                 651.0
# 2007-06-01                2480.0                3206.0
# 2007-07-01                2846.0                2693.0
# 2007-08-01               -3056.0               -3008.0
# 2007-09-01                3915.0                 997.0
# 2007-10-01                5676.0               -2480.0
# 2007-11-01                2434.0                1515.0
# 2007-12-01               -6752.0               -1388.0
# 2008-01-01                -600.0                3557.0
# 2008-02-01                 261.0                 265.0
# 2008-03-01                5113.0                1408.0
# 2008-04-01                1560.0                1271.0
# 2008-05-01                6643.0                 885.0
# 2008-06-01                1330.0                1978.0
# ...                          ...                   ...
# 2019-07-01                   NaN                   NaN
# 2019-08-01                   NaN                   NaN
# 2019-09-01                   NaN                   NaN
# 2019-10-01                   NaN                   NaN
# 2019-11-01                   NaN                   NaN
# 2019-12-01                   NaN                   NaN
# 2020-01-01                   NaN                   NaN
# 2020-02-01                   NaN                   NaN
# 2020-03-01                   NaN                   NaN
# 2020-04-01                   NaN                   NaN
# 2020-05-01                   NaN                   NaN
# 2007-02-01           NaN           NaN
# 2007-03-01           NaN           NaN
# 2007-04-01           NaN           NaN
# 2007-05-01           NaN           NaN
# 2007-06-01           NaN           NaN
# 2007-07-01           NaN           NaN
# 2007-08-01           NaN           NaN
# 2007-09-01           NaN           NaN
# 2007-10-01           NaN           NaN
# 2007-11-01           NaN           NaN
# 2007-12-01           NaN           NaN
# 2008-01-01           NaN           NaN
# 2008-02-01           NaN           NaN
# 2008-03-01           NaN           NaN
# 2008-04-01           NaN           NaN
# 2008-05-01           NaN           NaN
# 2008-06-01           NaN           NaN
# ...                  ...           ...
# 2019-07-01           NaN           NaN
# 2019-08-01           NaN           NaN
# 2019-09-01           NaN           NaN
# 2019-10-01           NaN           NaN
# 2019-11-01           NaN           NaN
# 2019-12-01           NaN           NaN
# 2020-01-01           NaN           NaN
# 2020-02-01           NaN           NaN
# 2020-03-01           NaN           NaN
# 2020-04-01           NaN           NaN
# 2020-05-01           NaN           NaN
# 2020-06-01           NaN           NaN
# 2020-07-01           NaN           NaN
# 2020-08-01           NaN           NaN
# 2020-09-01           NaN           NaN
# 2020-10-01           NaN           NaN
# 2020-11-01           NaN           NaN
# 2020-12-01           NaN           NaN
# 2021-01-01           NaN           NaN
# 2021-02-01           NaN           NaN
# 2021-03-01           NaN           NaN
# 2021-04-01           NaN           NaN
# 2021-05-01           NaN           NaN
# 2021-06-01           NaN           NaN
# 2021-07-01           NaN           NaN
# 2021-08-01           NaN           NaN
# 2021-09-01           NaN           NaN
# 2021-10-01           NaN           NaN
# 2021-11-01           NaN           NaN
# 2021-12-01           NaN           NaN
#
# [191 rows x 18 columns]

# %%
df_new['CLT_forecast'] = results_CLT.predict(start = 129, end = 190, dynamic= True)  
df_new[['CLT_LF', 'CLT_forecast']].ix[-191:].plot(figsize=(12, 8)).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('ts_predict_future.png', bbox_inches='tight')

# %%
df_new['RDU_forecast'] = results_RDU.predict(start = 129, end = 190, dynamic= True)  
df_new[['RDU_LF', 'RDU_forecast']].ix[-191:].plot(figsize=(12, 8)).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#plt.savefig('ts_predict_future.png', bbox_inches='tight')

# %%
df_new[['CLT_LF', 'CLT_forecast', 'RDU_LF', 'RDU_forecast']].ix[-191:].plot(figsize=(12, 8)).get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.xlabel('Year', fontsize=18)
plt.ylabel('Labor Force', fontsize=18)
plt.title('CLT vs RDU Labor Force', fontsize=20)
import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)
plt.savefig('CLT vs RDU Labor Force.jpeg', bbox_inches='tight')

# %%
df_new
# Out:
#               GSO_LF  GSO_UR     CLT_LF  CLT_UR    RDU_LF  RDU_UR  \
# 2006-01-01  360198.0     4.7  1014866.0     4.9  245718.0     3.8
# 2006-02-01  362938.0     5.0  1021495.0     5.2  247942.0     4.1
# 2006-03-01  364353.0     4.5  1027071.0     4.7  249102.0     3.7
# 2006-04-01  366655.0     4.5  1032285.0     4.7  248950.0     3.7
# 2006-05-01  370078.0     4.7  1040587.0     4.9  251530.0     3.9
# 2007-02-01       279388.0            3.9  152983.0     4.5
# 2007-03-01       280600.0            3.7  153051.0     4.4
# 2007-04-01       279468.0            3.2  152435.0     4.5
# 2007-05-01       282881.0            3.4  152670.0     4.4
# 2007-06-01       287631.0            3.8  153041.0     4.6
# 2007-07-01       290210.0            3.9  153054.0     4.7
# 2007-08-01       287895.0            3.8  152749.0     4.6
# 2007-09-01       284202.0            3.4  153414.0     4.7
# 2007-10-01       282542.0            3.4  153183.0     4.7
# 2007-11-01       283650.0            3.5  153835.0     4.7
# 2007-12-01       283388.0            3.7  153918.0     5.0
# 2008-01-01       283627.0            4.3  154063.0     5.0
# 2008-02-01       282719.0            4.3  153653.0     4.9
# 2008-03-01       284497.0            4.2  153908.0     5.1
# 2008-04-01       285724.0            3.7  153769.0     5.0
# 2008-05-01       289122.0            4.2  154303.0     5.4
# 2008-06-01       293496.0            4.6  154313.0     5.6
# ...                   ...            ...       ...     ...
# 2019-07-01            NaN            NaN       NaN     NaN
# 2019-08-01            NaN            NaN       NaN     NaN
# 2019-09-01            NaN            NaN       NaN     NaN
# 2019-10-01            NaN            NaN       NaN     NaN
# 2019-11-01            NaN            NaN       NaN     NaN
# 2019-12-01            NaN            NaN       NaN     NaN
# 2020-01-01            NaN            NaN       NaN     NaN
# 2020-02-01            NaN            NaN       NaN     NaN
# 2020-03-01            NaN            NaN       NaN     NaN
# 2020-04-01            NaN            NaN       NaN     NaN
# 2020-05-01            NaN            NaN       NaN     NaN
# 2020-06-01            NaN            NaN       NaN     NaN
# 2020-07-01            NaN            NaN       NaN     NaN
# 2020-08-01            NaN            NaN       NaN     NaN
# 2020-09-01            NaN            NaN       NaN     NaN
# 2020-10-01            NaN            NaN       NaN     NaN
# 2020-11-01            NaN            NaN       NaN     NaN
# 2020-12-01            NaN            NaN       NaN     NaN
# 2021-01-01            NaN            NaN       NaN     NaN
# 2021-02-01            NaN            NaN       NaN     NaN
# 2021-03-01            NaN            NaN       NaN     NaN
# 2021-04-01            NaN            NaN       NaN     NaN
# 2021-05-01            NaN            NaN       NaN     NaN
# 2021-06-01            NaN            NaN       NaN     NaN
# 2021-07-01            NaN            NaN       NaN     NaN
# 2021-08-01            NaN            NaN       NaN     NaN
# 2021-09-01            NaN            NaN       NaN     NaN
# 2021-10-01            NaN            NaN       NaN     NaN
# 2021-11-01            NaN            NaN       NaN     NaN
# 2021-12-01            NaN            NaN       NaN     NaN
#
#             CLT_first_difference  RDU_first_difference  \
# 2006-01-01                   NaN                   NaN
# 2006-02-01                6629.0                2224.0
# 2006-03-01                5576.0                1160.0
# 2006-04-01                5214.0                -152.0
# 2006-05-01                8302.0                2580.0
# 2006-06-01                2178.0                2691.0
# 2006-07-01                7031.0                3264.0
# 2006-08-01                4609.0               -1409.0
# 2006-09-01                1903.0                -680.0
# 2006-10-01                8734.0                1231.0
# 2006-11-01                3505.0                1375.0
# 2006-12-01               -7020.0                -475.0
# 2007-01-01               -5073.0               -4842.0
# 2007-02-01                 662.0                1251.0
# 2020-10-01                            NaN                            NaN
# 2020-11-01                            NaN                            NaN
# 2020-12-01                            NaN                            NaN
# 2021-01-01                            NaN                            NaN
# 2021-02-01                            NaN                            NaN
# 2021-03-01                            NaN                            NaN
# 2021-04-01                            NaN                            NaN
# 2021-05-01                            NaN                            NaN
# 2021-06-01                            NaN                            NaN
# 2021-07-01                            NaN                            NaN
# 2021-08-01                            NaN                            NaN
# 2021-09-01                            NaN                            NaN
# 2021-10-01                            NaN                            NaN
# 2021-11-01                            NaN                            NaN
# 2021-12-01                            NaN                            NaN
#
#             CLT_forecast   RDU_forecast
# 2006-01-01           NaN            NaN
# 2006-02-01           NaN            NaN
# 2006-03-01           NaN            NaN
# 2006-04-01           NaN            NaN
# 2006-05-01           NaN            NaN
# 2006-06-01           NaN            NaN
# 2006-07-01           NaN            NaN
# 2006-08-01           NaN            NaN
# 2006-09-01           NaN            NaN
# 2006-10-01           NaN            NaN
# 2006-11-01           NaN            NaN
# 2006-12-01           NaN            NaN
# 2007-01-01           NaN            NaN
# 2007-02-01           NaN            NaN
# 2007-03-01           NaN            NaN
# 2007-04-01           NaN            NaN
# 2007-05-01           NaN            NaN
# 2007-06-01           NaN            NaN
# 2007-07-01           NaN            NaN
# 2007-08-01           NaN            NaN
# 2007-09-01           NaN            NaN
# 2007-10-01           NaN            NaN
# 2007-11-01           NaN            NaN
# 2007-12-01           NaN            NaN
# 2008-01-01           NaN            NaN
# 2008-02-01           NaN            NaN
# 2008-03-01           NaN            NaN
# 2008-04-01           NaN            NaN
# 2008-05-01           NaN            NaN
# 2008-06-01           NaN            NaN
# ...                  ...            ...
# 2019-07-01  1.358094e+06  313279.883428
# 2019-08-01  1.350229e+06  310134.453072
# 2019-09-01  1.355915e+06  313917.275854
# 2019-10-01  1.370143e+06  315061.754305
# 2019-11-01  1.368932e+06  315143.864585
# 2019-12-01  1.367780e+06  314616.313612
# 2020-01-01  1.370241e+06  315568.806907
# 2020-02-01  1.379194e+06  320160.668521
# 2020-03-01  1.395490e+06  322905.510063
# 2020-04-01  1.391958e+06  321364.203882
# 2020-05-01  1.392724e+06  321983.950660
# 2020-06-01  1.397061e+06  319309.455934
# 2020-07-01  1.389772e+06  321696.273647
# 2020-08-01  1.381908e+06  318550.824813
# 2020-09-01  1.387594e+06  322333.980095
# 2020-10-01  1.401821e+06  323478.467844
# 2020-11-01  1.400609e+06  323560.572966
# 2020-12-01  1.399458e+06  323033.009772
# 2021-01-01  1.401920e+06  323985.528381
# 2021-02-01  1.410872e+06  328577.365870
# 2021-03-01  1.427167e+06  331322.175197
# 2021-04-01  1.423635e+06  329780.898730
# 2021-05-01  1.424401e+06  330400.666172
# 2021-06-01  1.428737e+06  327726.159881
# 2021-07-01  1.421449e+06  330112.976918
# 2021-08-01  1.413586e+06  326967.530114
# 2021-09-01  1.419271e+06  330750.648864
# 2021-10-01  1.433497e+06  331895.135592
# 2021-11-01  1.432286e+06  331977.241280
# 2021-12-01           NaN            NaN
#
# [191 rows x 18 columns]
